# %%
import pandas as pd

df = pd.read_csv("/content/sales2.xlsx - Sheet1.csv")

print(df.head())
print(df.info())
# Out:
#   Invoice StockCode                          Description  Quantity  \
# 0  489434     85048  15CM CHRISTMAS GLASS BALL 20 LIGHTS        12
# 1  489434    79323P                   PINK CHERRY LIGHTS        12
# 2  489434    79323W                  WHITE CHERRY LIGHTS        12
# 3  489434     22041         RECORD FRAME 7" SINGLE SIZE         48
# 4  489434     21232       STRAWBERRY CERAMIC TRINKET BOX        24
#
#     InvoiceDate  Price  Customer ID         Country
# 0  12/1/09 7:45   6.95      13085.0  United Kingdom
# 1  12/1/09 7:45   6.75      13085.0  United Kingdom
# 2  12/1/09 7:45   6.75      13085.0  United Kingdom
# 3  12/1/09 7:45   2.10      13085.0  United Kingdom
# 4  12/1/09 7:45   1.25      13085.0  United Kingdom
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 293794 entries, 0 to 293793
# Data columns (total 8 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   Invoice      293794 non-null  object
#  1   StockCode    293794 non-null  object
#  2   Description  291731 non-null  object
#  3   Quantity     293794 non-null  int64
#  4   InvoiceDate  293794 non-null  object
#  5   Price        293794 non-null  float64
#  6   Customer ID  231379 non-null  float64
#  7   Country      293794 non-null  object
# dtypes: float64(2), int64(1), object(5)
# memory usage: 17.9+ MB
# None

# %%
df.isnull().sum()
# Out:
# Invoice            0
# StockCode          0
# Description     2063
# Quantity           0
# InvoiceDate        0
# Price              0
# Customer ID    62415
# Country            0
# dtype: int64

# %%
df = df.dropna(subset=["Customer ID"])
df = df[~df["Invoice"].astype(str).str.startswith("C")]
df =df[(df["Quantity"] > 0) & (df["Price"] > 0)]
df = df.drop_duplicates()

# %%
df["TotalAmount"] = df["Quantity"] * df["Price"]
print(df["TotalAmount"].head())
# Out:
# 0     83.4
# 1     81.0
# 2     81.0
# 3    100.8
# 4     30.0
# Name: TotalAmount, dtype: float64

# %%
df['InvoiceDate'] = pd.to_datetime(df['InvoiceDate'])
reference_date = df["InvoiceDate"].max() + pd.Timedelta(days=1)

rfm = df.groupby("Customer ID").agg(
    Recency=("InvoiceDate",
             lambda x: (reference_date - x.max()).days),
    Frequency=("Invoice", "nunique"),
    Monetary=("TotalAmount", "sum")
)

print(rfm.head())
# Out:
# /tmp/ipykernel_997/4063197989.py:1: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df['InvoiceDate'] = pd.to_datetime(df['InvoiceDate'])
#              Recency  Frequency  Monetary
# Customer ID
# 12346.0           37         11    372.86
# 12349.0           78          2   1268.52
# 12355.0           75          1    488.21
# 12358.0           58          2   1697.93
# 12359.0           43          5   2012.03

# %%
from sklearn.preprocessing import StandardScaler

features = ["Recency", "Frequency", "Monetary"]

scaler = StandardScaler()

rfm_scaled = scaler.fit_transform(rfm[features])

# %%
from sklearn.cluster import KMeans
import matplotlib.pyplot as plt

inertia = []

for k in range(2,11):
    model = KMeans(
        n_clusters=k,
        random_state=42,
        n_init=10
    )

    model.fit(rfm_scaled)
    inertia.append(model.inertia_)

plt.plot(range(2, 11), inertia, marker="o")
plt.xlabel("Number of Clusters")
plt.ylabel("Inertia")
plt.title("Elbow Method")
plt.show()

# %%
kmeans = KMeans(
    n_clusters=2,
    random_state=42,
    n_init=10
)

rfm["Cluster"] = kmeans.fit_predict(rfm_scaled)

# %%
from sklearn.metrics import silhouette_score

silhouette = silhouette_score(
    rfm_scaled,
    rfm["Cluster"]
)

print("Silhouette Score:", silhouette)
# Out:
# Silhouette Score: 0.895929532268914

# %%
from sklearn.metrics import davies_bouldin_score

db_index = davies_bouldin_score(
    rfm_scaled,
    rfm["Cluster"]
)

print("Davies-Bouldin Index:", db_index)
# Out:
# Davies-Bouldin Index: 0.6882377538247715

# %%
plt.figure(figsize=(8, 6))

plt.scatter(
    rfm["Frequency"],
    rfm["Monetary"],
    c=rfm["Cluster"]
)

plt.xlabel("Frequency")
plt.ylabel("Monetary")
plt.title("Customer Clusters")
plt.show()

# %%
cluster_summary = rfm.groupby("Cluster")[
    ["Recency", "Frequency", "Monetary"]
].mean()

print(cluster_summary)
# Out:
#            Recency  Frequency      Monetary
# Cluster
# 0        81.513137   3.117126   1215.291741
# 1         5.555556  56.888889  60910.011111
